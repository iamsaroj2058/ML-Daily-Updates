# %% [markdown]
# ### Here i am testing  how  the random api's showing the  data in json format

# %%
import requests

url = "https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page=1&sort_by=popularity.desc"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJhNTZmNGIzNmQwOGI1ZDljYzc1MTg4Yzk2NWMyNzk0MiIsIm5iZiI6MTc2Nzc2Njc5OS4xOTYsInN1YiI6IjY5NWRmYjBmNGI3ZGE2NzgzNmYyOGZiOSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.Q8Xd429ICWkJbpX_YKq8V-lDps7k5Vj4nDraWKv3f9g"
}

response = requests.get(url, headers=headers)
result = response.json()['result']


print(result)
# Out:
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/ebyxeBh56QNXxSJgTnmz7fXAlwk.jpg', 'genre_ids': [28, 878, 12], 'id': 1242898, 'original_language': 'en', 'original_title': 'Predator: Badlands', 'overview': 'Cast out from his clan, a young Predator finds an unlikely ally in a damaged android and embarks on a treacherous journey in search of the ultimate adversary.', 'popularity': 816.4153, 'poster_path': '/pHpq9yNUIo6aDoCXEBzjSolywgz.jpg', 'release_date': '2025-11-05', 'title': 'Predator: Badlands', 'video': False, 'vote_average': 7.759, 'vote_count': 1292}, {'adult': False, 'backdrop_path': '/vMxOmgmBGegjVObjlb8ugsjGgkD.jpg', 'genre_ids': [10752, 28, 18], 'id': 1252037, 'original_language': 'de', 'original_title': 'Der Tiger', 'overview': "A German Tiger tank crew is sent on a dangerous mission to rescue the missing officer Paul von Hardenburg from a top-secret bunker behind enemy lines. As they make their way through the lethal no-man's land, they must confront not only th
# ...

# %% [markdown]
# ###  I am making a  file from where  i can fetch data from the api orf the website.

# %%
import pandas as pd

# %% [markdown]
# ####  Converting list into dataframe

# %%
pd.DataFrame(result)[['id','title','overview','release_date','popularity','vote_average','vote_count']]
# Out:
#          id                                           title  \
# 0   1242898                              Predator: Badlands
# 1   1252037                                        The Tank
# 2     83533                            Avatar: Fire and Ash
# 3   1242501                                         Icefall
# 4   1084242                                      Zootopia 2
# 5    628847                                      Trap House
# 6   1511417                              Bāhubali: The Epic
# 7   1368166                                   The Housemaid
# 8   1311031  Demon Slayer: Kimetsu no Yaiba Infinity Castle
# 9    755898                               War of the Worlds
# 10  1228246                       Five Nights at Freddy's 2
# 11  1131759                 Omniscient Reader: The Prophecy
# 12  1034716                      People We Meet on Vacation
# 13   425274                   Now You See Me: Now You Don't
# 14  1512623                                          Risqué
# ...
